# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
basedir = '../'
sys.path.append(basedir)

import pylab as plt
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud
from hlda.sampler import HierarchicalLDA
from ipywidgets import widgets
from IPython.core.display import HTML, display

import string
import glob
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
conda install -c https://conda.anaconda.org/conda-forge wordcloud
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\De\anaconda3
#
#   added / updated specs:
#     - wordcloud
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2022.05  |           py39_0           7 KB
#     aiohttp-3.8.1              |   py39hb82d6ee_1         545 KB  conda-forge
#     aiosignal-1.2.0            |     pyhd8ed1ab_0          12 KB  conda-forge
#     anaconda-custom            |           py39_1           4 KB
#     argon2-cffi-bindings-21.2.0|   py39hb82d6ee_2          34 KB  conda-forge
#     asttokens-2.0.5            |     pyhd8ed1ab_0          21 KB  conda-forge
#     async-timeout-4.0.2        |     pyhd8ed1ab_0           9 KB  conda-forge
#     automat-20.2.0             |             py_0          30 KB  conda-forge
#     boto3-1.24.7               |     pyhd8ed1ab_0          71 KB  conda-forge
#     botocore-1.27.7            |     pyhd8ed1ab_0         5.5 MB  conda-forge
#     ca-certificates-2022.5.18.1|       h5b45459_0         180 KB  conda-forge
#     cachetools-5.0.0           |     pyhd8ed1ab_0          12 KB  conda-forge
#     certifi-2022.5.18.1        |   py39hcbf5309_0         151 KB  conda-forge
#     colorcet-3.0.0             |     pyhd8ed1ab_0         1.5 MB  conda-forge
#     constantly-15.1.0          |             py_0           9 KB  conda-forge
#     cssselect-1.1.0            |             py_0          18 KB  conda-forge
#     cython-0.29.30             |   py39h415ef7b_0         1.9 MB  conda-forge
#     datashader-0.14.0          |     pyh6c4a22f_0        16.6 MB  conda-forge
#     datashape-0.5.4            |             py_1          49 KB  conda-forge
#     executing-0.8.3            |     pyhd8ed1ab_0          18 KB  conda-forge
#     frozenlist-1.3.0           |   py39hb82d6ee_1          40 KB  conda-forge
#     gensim-4.2.0               |   py39h2e25243_0        22.3 MB  conda-forge
#     google-api-core-2.8.1      |     pyhd8ed1ab_0          70 KB  conda-forge
#     google-auth-2.7.0          |     pyh6c4a22f_1          87 KB  conda-forge
#     google-cloud-core-2.3.1    |     pyhd8ed1ab_0          27 KB  conda-forge
#     google-cloud-storage-2.4.0 |     pyh6c4a22f_0          74 KB  conda-forge
#     google-crc32c-1.1.2        |   py39h3fc79e4_3          26 KB  conda-forge
#     google-resumable-media-2.3.3|     pyhd8ed1ab_0          42 KB  conda-forge
#     googleapis-common-protos-1.56.2|   py39h35db3c3_0         123 KB  conda-forge
#     grpcio-1.42.0              |   py39hc60d5dd_0         1.9 MB
#     holoviews-1.14.9           |     pyhd8ed1ab_0         3.5 MB  conda-forge
#     hvplot-0.8.0               |     pyh6c4a22f_0         3.0 MB  conda-forge
#     hyperlink-21.0.0           |     pyhd3deb0d_0          71 KB  conda-forge
#     incremental-21.3.0         |     pyhd8ed1ab_0          16 KB  conda-forge
#     intake-0.6.5               |     pyhd8ed1ab_0         115 KB  conda-forge
#     itemadapter-0.6.0          |     pyhd8ed1ab_0          13 KB  conda-forge
#     itemloaders-1.0.4          |     pyhd8ed1ab_0          14 KB  conda-forge
#     jmespath-1.0.0             |     pyhd8ed1ab_0          21 KB  conda-forge
#     jq-1.6                     |       haa95532_1         992 KB
#     libcrc32c-1.1.2            |       h0e60522_0          25 KB  conda-forge
#     libprotobuf-3.19.1         |       h23ce68f_0         1.9 MB
#     markdown-3.3.7             |     pyhd8ed1ab_0          67 KB  conda-forge
#     multidict-6.0.2            |   py39hb82d6ee_1          47 KB  conda-forge
#     openssl-1.1.1o             |       h8ffe710_0         5.7 MB  conda-forge
#     panel-0.13.1               |     pyhd8ed1ab_0        12.3 MB  conda-forge
#     param-1.12.1               |     pyh6c4a22f_0          72 KB  conda-forge
#     parsel-1.6.0               |             py_0          15 KB  conda-forge
#     plotly-5.8.2               |     pyhd8ed1ab_0         6.9 MB  conda-forge
#     protego-0.2.1              |     pyhd8ed1ab_0         2.6 MB  conda-forge
#     protobuf-3.19.1            |   py39hd77b12b_0         238 KB
#     pure_eval-0.2.2            |     pyhd8ed1ab_0          14 KB  conda-forge
#     pyasn1-0.4.8               |             py_0          53 KB  conda-forge
#     pyasn1-modules-0.2.7       |             py_0          60 KB  conda-forge
#     pyct-0.4.6                 |             py_0           3 KB  conda-forge
#     pyct-core-0.4.6            |             py_0          13 KB  conda-forge
#     pydispatcher-2.0.5         |             py_1          12 KB  conda-forge
#     pyhamcrest-2.0.3           |     pyhd8ed1ab_0          30 KB  conda-forge
#     python-fastjsonschema-2.15.3|     pyhd8ed1ab_0         243 KB  conda-forge
#     python-snappy-0.6.0        |   py39h1d87f24_2          33 KB  conda-forge
#     pyu2f-0.1.5                |     pyhd8ed1ab_0          31 KB  conda-forge
#     pyviz_comms-2.2.0          |     pyhd8ed1ab_0          31 KB  conda-forge
#     queuelib-1.6.2             |     pyhd8ed1ab_0          14 KB  conda-forge
#     requests-file-1.5.1        |     pyh9f0ad1d_0           7 KB  conda-forge
#     rsa-4.8                    |     pyhd8ed1ab_0          31 KB  conda-forge
#     s3transfer-0.6.0           |     pyhd8ed1ab_0          55 KB  conda-forge
#     scrapy-2.6.1               |   py39haa95532_0         386 KB
#     service_identity-18.1.0    |             py_0          12 KB  conda-forge
#     smart_open-6.0.0           |     pyhd8ed1ab_0          43 KB  conda-forge
#     stack_data-0.2.0           |     pyhd8ed1ab_0          21 KB  conda-forge
#     tabulate-0.8.9             |     pyhd8ed1ab_0          26 KB  conda-forge
#     tenacity-8.0.1             |     pyhd8ed1ab_0          21 KB  conda-forge
#     tldextract-3.3.0           |     pyhd8ed1ab_0          92 KB  conda-forge
#
# Note: you may need to restart the kernel to use updated packages.
#     tomli-2.0.1                |     pyhd8ed1ab_0          16 KB  conda-forge
#     twisted-22.4.0             |   py39hb82d6ee_0         5.1 MB  conda-forge
#     twisted-iocpsupport-1.0.2  |   py39hb82d6ee_2          44 KB  conda-forge
#     typing-extensions-3.10.0.2 |       hd3eb1b0_0          12 KB
#     w3lib-1.22.0               |     pyh9f0ad1d_0          21 KB  conda-forge
#     websocket-client-1.3.2     |     pyhd8ed1ab_0          41 KB  conda-forge
#     wordcloud-1.8.1            |   py39hb82d6ee_2         196 KB  conda-forge
#     xarray-2022.3.0            |     pyhd8ed1ab_0         650 KB  conda-forge
#     yarl-1.7.2                 |   py39hb82d6ee_2         127 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        96.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/win-64::_anaconda_depends-2022.05-py39_0
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda==2021.11=py39_0
#   aiohttp            conda-forge/win-64::aiohttp-3.8.1-py39hb82d6ee_1
#   aiosignal          conda-forge/noarch::aiosignal-1.2.0-pyhd8ed1ab_0
#   argon2-cffi-bindi~ conda-forge/win-64::argon2-cffi-bindings-21.2.0-py39hb82d6ee_2
#   asttokens          conda-forge/noarch::asttokens-2.0.5-pyhd8ed1ab_0
#   async-timeout      conda-forge/noarch::async-timeout-4.0.2-pyhd8ed1ab_0
#   automat            conda-forge/noarch::automat-20.2.0-py_0
#   boto3              conda-forge/noarch::boto3-1.24.7-pyhd8ed1ab_0
#   botocore           conda-forge/noarch::botocore-1.27.7-pyhd8ed1ab_0
#   cachetools         conda-forge/noarch::cachetools-5.0.0-pyhd8ed1ab_0
#   colorcet           conda-forge/noarch::colorcet-3.0.0-pyhd8ed1ab_0
#   constantly         conda-forge/noarch::constantly-15.1.0-py_0
#   cssselect          conda-forge/noarch::cssselect-1.1.0-py_0
#   cython             conda-forge/win-64::cython-0.29.30-py39h415ef7b_0
#   datashader         conda-forge/noarch::datashader-0.14.0-pyh6c4a22f_0
#   datashape          conda-forge/noarch::datashape-0.5.4-py_1
#   executing          conda-forge/noarch::executing-0.8.3-pyhd8ed1ab_0
#   frozenlist         conda-forge/win-64::frozenlist-1.3.0-py39hb82d6ee_1
#   gensim             conda-forge/win-64::gensim-4.2.0-py39h2e25243_0
#   google-api-core    conda-forge/noarch::google-api-core-2.8.1-pyhd8ed1ab_0
#   google-auth        conda-forge/noarch::google-auth-2.7.0-pyh6c4a22f_1
#   google-cloud-core  conda-forge/noarch::google-cloud-core-2.3.1-pyhd8ed1ab_0
#   google-cloud-stor~ conda-forge/noarch::google-cloud-storage-2.4.0-pyh6c4a22f_0
#   google-crc32c      conda-forge/win-64::google-crc32c-1.1.2-py39h3fc79e4_3
#   google-resumable-~ conda-forge/noarch::google-resumable-media-2.3.3-pyhd8ed1ab_0
#   googleapis-common~ conda-forge/win-64::googleapis-common-protos-1.56.2-py39h35db3c3_0
#   grpcio             pkgs/main/win-64::grpcio-1.42.0-py39hc60d5dd_0
#   holoviews          conda-forge/noarch::holoviews-1.14.9-pyhd8ed1ab_0
#   hvplot             conda-forge/noarch::hvplot-0.8.0-pyh6c4a22f_0
#   hyperlink          conda-forge/noarch::hyperlink-21.0.0-pyhd3deb0d_0
#   incremental        conda-forge/noarch::incremental-21.3.0-pyhd8ed1ab_0
#   intake             conda-forge/noarch::intake-0.6.5-pyhd8ed1ab_0
#   itemadapter        conda-forge/noarch::itemadapter-0.6.0-pyhd8ed1ab_0
#   itemloaders        conda-forge/noarch::itemloaders-1.0.4-pyhd8ed1ab_0
#   jmespath           conda-forge/noarch::jmespath-1.0.0-pyhd8ed1ab_0
#   jq                 pkgs/main/win-64::jq-1.6-haa95532_1
#   libcrc32c          conda-forge/win-64::libcrc32c-1.1.2-h0e60522_0
#   libprotobuf        pkgs/main/win-64::libprotobuf-3.19.1-h23ce68f_0
#   markdown           conda-forge/noarch::markdown-3.3.7-pyhd8ed1ab_0
#   multidict          conda-forge/win-64::multidict-6.0.2-py39hb82d6ee_1
#   panel              conda-forge/noarch::panel-0.13.1-pyhd8ed1ab_0
#   param              conda-forge/noarch::param-1.12.1-pyh6c4a22f_0
#   parsel             conda-forge/noarch::parsel-1.6.0-py_0
#   plotly             conda-forge/noarch::plotly-5.8.2-pyhd8ed1ab_0
#   protego            conda-forge/noarch::protego-0.2.1-pyhd8ed1ab_0
#   protobuf           pkgs/main/win-64::protobuf-3.19.1-py39hd77b12b_0
#   pure_eval          conda-forge/noarch::pure_eval-0.2.2-pyhd8ed1ab_0
#   pyasn1             conda-forge/noarch::pyasn1-0.4.8-py_0
#   pyasn1-modules     conda-forge/noarch::pyasn1-modules-0.2.7-py_0
#   pyct               conda-forge/noarch::pyct-0.4.6-py_0
#   pyct-core          conda-forge/noarch::pyct-core-0.4.6-py_0
#   pydispatcher       conda-forge/noarch::pydispatcher-2.0.5-py_1
#   pyhamcrest         conda-forge/noarch::pyhamcrest-2.0.3-pyhd8ed1ab_0
#   python-fastjsonsc~ conda-forge/noarch::python-fastjsonschema-2.15.3-pyhd8ed1ab_0
#   python-snappy      conda-forge/win-64::python-snappy-0.6.0-py39h1d87f24_2
#   pyu2f              conda-forge/noarch::pyu2f-0.1.5-pyhd8ed1ab_0
#   pyviz_comms        conda-forge/noarch::pyviz_comms-2.2.0-pyhd8ed1ab_0
#   queuelib           conda-forge/noarch::queuelib-1.6.2-pyhd8ed1ab_0
#   requests-file      conda-forge/noarch::requests-file-1.5.1-pyh9f0ad1d_0
#   rsa                conda-forge/noarch::rsa-4.8-pyhd8ed1ab_0
#   s3transfer         conda-forge/noarch::s3transfer-0.6.0-pyhd8ed1ab_0
#   scrapy             pkgs/main/win-64::scrapy-2.6.1-py39haa95532_0
#   service_identity   conda-forge/noarch::service_identity-18.1.0-py_0
#   smart_open         conda-forge/noarch::smart_open-6.0.0-pyhd8ed1ab_0
#   stack_data         conda-forge/noarch::stack_data-0.2.0-pyhd8ed1ab_0
#   tabulate           conda-forge/noarch::tabulate-0.8.9-pyhd8ed1ab_0
#   tenacity           conda-forge/noarch::tenacity-8.0.1-pyhd8ed1ab_0
#   tldextract         conda-forge/noarch::tldextract-3.3.0-pyhd8ed1ab_0
#   tomli              conda-forge/noarch::tomli-2.0.1-pyhd8ed1ab_0
#   twisted            conda-forge/win-64::twisted-22.4.0-py39hb82d6ee_0
#   twisted-iocpsuppo~ conda-forge/win-64::twisted-iocpsupport-1.0.2-py39hb82d6ee_2
#   typing-extensions  pkgs/main/noarch::typing-extensions-3.10.0.2-hd3eb1b0_0
#   w3lib              conda-forge/noarch::w3lib-1.22.0-pyh9f0ad1d_0
#   websocket-client   conda-forge/noarch::websocket-client-1.3.2-pyhd8ed1ab_0
#   wordcloud          conda-forge/win-64::wordcloud-1.8.1-py39hb82d6ee_2
#   xarray             conda-forge/noarch::xarray-2022.3.0-pyhd8ed1ab_0
#   yarl               conda-forge/win-64::yarl-1.7.2-py39hb82d6ee_2
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2021.10.26~ --> conda-forge::ca-certificates-2022.5.18.1-h5b45459_0
#   certifi            pkgs/main::certifi-2021.10.8-py39haa9~ --> conda-forge::certifi-2022.5.18.1-py39hcbf5309_0
#   openssl              pkgs/main::openssl-1.1.1l-h2bbff1b_0 --> conda-forge::openssl-1.1.1o-h8ffe710_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2021.11-py39_0 --> custom-py39_1
#
#
#
# Downloading and Extracting Packages
#
# pydispatcher-2.0.5   | 12 KB     |            |   0%
# pydispatcher-2.0.5   | 12 KB     | ########## | 100%
# pydispatcher-2.0.5   | 12 KB     | ########## | 100%
#
# executing-0.8.3      | 18 KB     |            |   0%
# executing-0.8.3      | 18 KB     | ########## | 100%
#
# datashader-0.14.0    | 16.6 MB   |            |   0%
# datashader-0.14.0    | 16.6 MB   |            |   0%
# datashader-0.14.0    | 16.6 MB   | 1          |   1%
# datashader-0.14.0    | 16.6 MB   | 2          |   2%
# datashader-0.14.0    | 16.6 MB   | 3          |   3%
# datashader-0.14.0    | 16.6 MB   | 4          |   4%
# datashader-0.14.0    | 16.6 MB   | 5          |   5%
# datashader-0.14.0    | 16.6 MB   | 6          |   6%
# datashader-0.14.0    | 16.6 MB   | 7          |   7%
# datashader-0.14.0    | 16.6 MB   | 8          |   8%
# datashader-0.14.0    | 16.6 MB   | #          |  11%
# datashader-0.14.0    | 16.6 MB   | #2         |  13%
# datashader-0.14.0    | 16.6 MB   | #3         |  14%
# datashader-0.14.0    | 16.6 MB   | #4         |  15%
# datashader-0.14.0    | 16.6 MB   | #6         |  16%
# datashader-0.14.0    | 16.6 MB   | #7         |  17%
# datashader-0.14.0    | 16.6 MB   | #7         |  18%
# datashader-0.14.0    | 16.6 MB   | #8         |  19%
# datashader-0.14.0    | 16.6 MB   | #9         |  20%
# datashader-0.14.0    | 16.6 MB   | ##1        |  22%
# datashader-0.14.0    | 16.6 MB   | ##3        |  24%
# datashader-0.14.0    | 16.6 MB   | ##4        |  25%
# datashader-0.14.0    | 16.6 MB   | ##6        |  26%
# datashader-0.14.0    | 16.6 MB   | ##7        |  27%
# datashader-0.14.0    | 16.6 MB   | ##8        |  28%
# datashader-0.14.0    | 16.6 MB   | ##9        |  29%
# datashader-0.14.0    | 16.6 MB   | ###        |  30%
# datashader-0.14.0    | 16.6 MB   | ###1       |  31%
# datashader-0.14.0    | 16.6 MB   | ###2       |  32%
# datashader-0.14.0    | 16.6 MB   | ###3       |  33%
# datashader-0.14.0    | 16.6 MB   | ###4       |  34%
# datashader-0.14.0    | 16.6 MB   | ###5       |  35%
# datashader-0.14.0    | 16.6 MB   | ###6       |  37%
# datashader-0.14.0    | 16.6 MB   | ###7       |  37%
# datashader-0.14.0    | 16.6 MB   | ###8       |  39%
# datashader-0.14.0    | 16.6 MB   | ###9       |  40%
# datashader-0.14.0    | 16.6 MB   | ####       |  41%
# datashader-0.14.0    | 16.6 MB   | ####1      |  42%
# datashader-0.14.0    | 16.6 MB   | ####2      |  42%
# datashader-0.14.0    | 16.6 MB   | ####3      |  43%
# datashader-0.14.0    | 16.6 MB   | ####4      |  44%
# datashader-0.14.0    | 16.6 MB   | ####5      |  45%
# datashader-0.14.0    | 16.6 MB   | ####6      |  46%
# datashader-0.14.0    | 16.6 MB   | ####7      |  47%
# datashader-0.14.0    | 16.6 MB   | ####8      |  48%
# datashader-0.14.0    | 16.6 MB   | ####9      |  49%
# datashader-0.14.0    | 16.6 MB   | #####      |  50%
# datashader-0.14.0    | 16.6 MB   | #####1     |  51%
# datashader-0.14.0    | 16.6 MB   | #####2     |  52%
# datashader-0.14.0    | 16.6 MB   | #####3     |  53%
# datashader-0.14.0    | 16.6 MB   | #####3     |  54%
# datashader-0.14.0    | 16.6 MB   | #####4     |  55%
# datashader-0.14.0    | 16.6 MB   | #####6     |  56%
# datashader-0.14.0    | 16.6 MB   | #####6     |  57%
# datashader-0.14.0    | 16.6 MB   | #####7     |  58%
# datashader-0.14.0    | 16.6 MB   | #####9     |  59%
# datashader-0.14.0    | 16.6 MB   | #####9     |  60%
# datashader-0.14.0    | 16.6 MB   | ######     |  61%
# datashader-0.14.0    | 16.6 MB   | ######1    |  62%
# datashader-0.14.0    | 16.6 MB   | ######2    |  63%
# datashader-0.14.0    | 16.6 MB   | ######4    |  64%
# datashader-0.14.0    | 16.6 MB   | ######7    |  67%
# datashader-0.14.0    | 16.6 MB   | #######1   |  71%
# datashader-0.14.0    | 16.6 MB   | ########1  |  82%
# datashader-0.14.0    | 16.6 MB   | #########2 |  93%
# datashader-0.14.0    | 16.6 MB   | ########## | 100%
# datashader-0.14.0    | 16.6 MB   | ########## | 100%
#
# google-api-core-2.8. | 70 KB     |            |   0%
# google-api-core-2.8. | 70 KB     | ##2        |  23%
# google-api-core-2.8. | 70 KB     | ########## | 100%
# google-api-core-2.8. | 70 KB     | ########## | 100%
#
# hyperlink-21.0.0     | 71 KB     |            |   0%
# hyperlink-21.0.0     | 71 KB     | ##2        |  23%
# hyperlink-21.0.0     | 71 KB     | ########## | 100%
#
# typing-extensions-3. | 12 KB     |            |   0%
# typing-extensions-3. | 12 KB     | ########## | 100%
# typing-extensions-3. | 12 KB     | ########## | 100%
#
# xarray-2022.3.0      | 650 KB    |            |   0%
# xarray-2022.3.0      | 650 KB    | 2          |   2%
# xarray-2022.3.0      | 650 KB    | ########## | 100%
# xarray-2022.3.0      | 650 KB    | ########## | 100%
#
# datashape-0.5.4      | 49 KB     |            |   0%
# datashape-0.5.4      | 49 KB     | ###2       |  33%
# datashape-0.5.4      | 49 KB     | ########## | 100%
#
# panel-0.13.1         | 12.3 MB   |            |   0%
# panel-0.13.1         | 12.3 MB   |            |   0%
# panel-0.13.1         | 12.3 MB   | ##1        |  21%
# panel-0.13.1         | 12.3 MB   | ####       |  41%
# panel-0.13.1         | 12.3 MB   | #####9     |  60%
# panel-0.13.1         | 12.3 MB   | ########## | 100%
# panel-0.13.1         | 12.3 MB   | ########## | 100%
#
# python-snappy-0.6.0  | 33 KB     |            |   0%
# python-snappy-0.6.0  | 33 KB     | ####8      |  48%
# python-snappy-0.6.0  | 33 KB     | ########## | 100%
#
# service_identity-18. | 12 KB     |            |   0%
# service_identity-18. | 12 KB     | ########## | 100%
# service_identity-18. | 12 KB     | ########## | 100%
#
# pyviz_comms-2.2.0    | 31 KB     |            |   0%
# pyviz_comms-2.2.0    | 31 KB     | #####2     |  52%
# pyviz_comms-2.2.0    | 31 KB     | ########## | 100%
#
# param-1.12.1         | 72 KB     |            |   0%
# param-1.12.1         | 72 KB     | ##2        |  22%
# param-1.12.1         | 72 KB     | ########## | 100%
#
# requests-file-1.5.1  | 7 KB      |            |   0%
# requests-file-1.5.1  | 7 KB      | ########## | 100%
# requests-file-1.5.1  | 7 KB      | ########## | 100%
#
# aiohttp-3.8.1        | 545 KB    |            |   0%
# aiohttp-3.8.1        | 545 KB    | 2          |   3%
# aiohttp-3.8.1        | 545 KB    | ######1    |  62%
# aiohttp-3.8.1        | 545 KB    | ########## | 100%
# aiohttp-3.8.1        | 545 KB    | ########## | 100%
#
# libcrc32c-1.1.2      | 25 KB     |            |   0%
# libcrc32c-1.1.2      | 25 KB     | ######3    |  64%
# libcrc32c-1.1.2      | 25 KB     | ########## | 100%
#
# google-cloud-storage | 74 KB     |            |   0%
# google-cloud-storage | 74 KB     | ##1        |  22%
# google-cloud-storage | 74 KB     | ########## | 100%
#
# tldextract-3.3.0     | 92 KB     |            |   0%
# tldextract-3.3.0     | 92 KB     | #7         |  17%
# tldextract-3.3.0     | 92 KB     | ########## | 100%
#
# argon2-cffi-bindings | 34 KB     |            |   0%
# argon2-cffi-bindings | 34 KB     | ####6      |  46%
# argon2-cffi-bindings | 34 KB     | ########## | 100%
#
# grpcio-1.42.0        | 1.9 MB    |            |   0%
# grpcio-1.42.0        | 1.9 MB    | ###3       |  34%
# grpcio-1.42.0        | 1.9 MB    | #########4 |  95%
# grpcio-1.42.0        | 1.9 MB    | ########## | 100%
#
# botocore-1.27.7      | 5.5 MB    |            |   0%
# botocore-1.27.7      | 5.5 MB    |            |   0%
# botocore-1.27.7      | 5.5 MB    |            |   1%
# botocore-1.27.7      | 5.5 MB    |            |   1%
# botocore-1.27.7      | 5.5 MB    | 1          |   1%
# botocore-1.27.7      | 5.5 MB    | 1          |   1%
# botocore-1.27.7      | 5.5 MB    | 1          |   2%
# botocore-1.27.7      | 5.5 MB    | 2          |   3%
# botocore-1.27.7      | 5.5 MB    | 3          |   4%
# botocore-1.27.7      | 5.5 MB    | 5          |   5%
# botocore-1.27.7      | 5.5 MB    | 7          |   7%
# botocore-1.27.7      | 5.5 MB    | 9          |   9%
# botocore-1.27.7      | 5.5 MB    | #1         |  11%
# botocore-1.27.7      | 5.5 MB    | #3         |  13%
# botocore-1.27.7      | 5.5 MB    | #5         |  15%
# botocore-1.27.7      | 5.5 MB    | #7         |  18%
# botocore-1.27.7      | 5.5 MB    | ##         |  20%
# botocore-1.27.7      | 5.5 MB    | ##3        |  23%
# botocore-1.27.7      | 5.5 MB    | ##8        |  28%
# botocore-1.27.7      | 5.5 MB    | ###2       |  32%
# botocore-1.27.7      | 5.5 MB    | ###7       |  37%
# botocore-1.27.7      | 5.5 MB    | ####3      |  44%
# botocore-1.27.7      | 5.5 MB    | #####      |  51%
# botocore-1.27.7      | 5.5 MB    | #####8     |  58%
# botocore-1.27.7      | 5.5 MB    | ######7    |  67%
# botocore-1.27.7      | 5.5 MB    | #######6   |  77%
# botocore-1.27.7      | 5.5 MB    | ########8  |  88%
# botocore-1.27.7      | 5.5 MB    | ########## | 100%
# botocore-1.27.7      | 5.5 MB    | ########## | 100%
#
# pyhamcrest-2.0.3     | 30 KB     |            |   0%
# pyhamcrest-2.0.3     | 30 KB     | #####3     |  53%
# pyhamcrest-2.0.3     | 30 KB     | ########## | 100%
#
# yarl-1.7.2           | 127 KB    |            |   0%
# yarl-1.7.2           | 127 KB    | #2         |  13%
# yarl-1.7.2           | 127 KB    | ########## | 100%
# yarl-1.7.2           | 127 KB    | ########## | 100%
#
# twisted-iocpsupport- | 44 KB     |            |   0%
# twisted-iocpsupport- | 44 KB     | ###6       |  36%
# twisted-iocpsupport- | 44 KB     | ########## | 100%
#
# anaconda-custom      | 4 KB      |            |   0%
# anaconda-custom      | 4 KB      | ########## | 100%
#
# websocket-client-1.3 | 41 KB     |            |   0%
# websocket-client-1.3 | 41 KB     | ########## | 100%
#
# cssselect-1.1.0      | 18 KB     |            |   0%
# cssselect-1.1.0      | 18 KB     | #########  |  91%
# cssselect-1.1.0      | 18 KB     | ########## | 100%
#
# protobuf-3.19.1      | 238 KB    |            |   0%
# protobuf-3.19.1      | 238 KB    | 6          |   7%
# protobuf-3.19.1      | 238 KB    | ########## | 100%
# protobuf-3.19.1      | 238 KB    | ########## | 100%
#
# multidict-6.0.2      | 47 KB     |            |   0%
# multidict-6.0.2      | 47 KB     | ###3       |  34%
# multidict-6.0.2      | 47 KB     | ########## | 100%
#
# pyct-core-0.4.6      | 13 KB     |            |   0%
# pyct-core-0.4.6      | 13 KB     | ########## | 100%
# pyct-core-0.4.6      | 13 KB     | ########## | 100%
#
# jq-1.6               | 992 KB    |            |   0%
# jq-1.6               | 992 KB    | ########## | 100%
# jq-1.6               | 992 KB    | ########## | 100%
#
# certifi-2022.5.18.1  | 151 KB    |            |   0%
# certifi-2022.5.18.1  | 151 KB    | ########## | 100%
# certifi-2022.5.18.1  | 151 KB    | ########## | 100%
#
# rsa-4.8              | 31 KB     |            |   0%
# rsa-4.8              | 31 KB     | ########## | 100%
# rsa-4.8              | 31 KB     | ########## | 100%
#
# smart_open-6.0.0     | 43 KB     |            |   0%
# smart_open-6.0.0     | 43 KB     | ########## | 100%
# smart_open-6.0.0     | 43 KB     | ########## | 100%
#
# parsel-1.6.0         | 15 KB     |            |   0%
# parsel-1.6.0         | 15 KB     | ########## | 100%
# parsel-1.6.0         | 15 KB     | ########## | 100%
#
# holoviews-1.14.9     | 3.5 MB    |            |   0%
# holoviews-1.14.9     | 3.5 MB    |            |   0%
# holoviews-1.14.9     | 3.5 MB    | #1         |  11%
# holoviews-1.14.9     | 3.5 MB    | ####       |  41%
# holoviews-1.14.9     | 3.5 MB    | ########2  |  82%
# holoviews-1.14.9     | 3.5 MB    | ########## | 100%
#
# cython-0.29.30       | 1.9 MB    |            |   0%
# cython-0.29.30       | 1.9 MB    |            |   1%
# cython-0.29.30       | 1.9 MB    | ########## | 100%
# cython-0.29.30       | 1.9 MB    | ########## | 100%
#
# stack_data-0.2.0     | 21 KB     |            |   0%
# stack_data-0.2.0     | 21 KB     | ########## | 100%
# stack_data-0.2.0     | 21 KB     | ########## | 100%
#
# itemadapter-0.6.0    | 13 KB     |            |   0%
# itemadapter-0.6.0    | 13 KB     | ########## | 100%
# itemadapter-0.6.0    | 13 KB     | ########## | 100%
#
# pure_eval-0.2.2      | 14 KB     |            |   0%
# pure_eval-0.2.2      | 14 KB     | ########## | 100%
#
# frozenlist-1.3.0     | 40 KB     |            |   0%
# frozenlist-1.3.0     | 40 KB     | ####       |  40%
# frozenlist-1.3.0     | 40 KB     | ########## | 100%
#
# google-resumable-med | 42 KB     |            |   0%
# google-resumable-med | 42 KB     | ###7       |  38%
# google-resumable-med | 42 KB     | ########## | 100%
#
# pyasn1-0.4.8         | 53 KB     |            |   0%
# pyasn1-0.4.8         | 53 KB     | ########## | 100%
# pyasn1-0.4.8         | 53 KB     | ########## | 100%
#
# async-timeout-4.0.2  | 9 KB      |            |   0%
# async-timeout-4.0.2  | 9 KB      | ########## | 100%
#
# _anaconda_depends-20 | 7 KB      |            |   0%
# _anaconda_depends-20 | 7 KB      | ########## | 100%
# _anaconda_depends-20 | 7 KB      | ########## | 100%
#
# tomli-2.0.1          | 16 KB     |            |   0%
# tomli-2.0.1          | 16 KB     | ########## | 100%
# tomli-2.0.1          | 16 KB     | ########## | 100%
#
# constantly-15.1.0    | 9 KB      |            |   0%
# constantly-15.1.0    | 9 KB      | ########## | 100%
# constantly-15.1.0    | 9 KB      | ########## | 100%
#
# tabulate-0.8.9       | 26 KB     |            |   0%
# tabulate-0.8.9       | 26 KB     | ######2    |  62%
# tabulate-0.8.9       | 26 KB     | ########## | 100%
#
# incremental-21.3.0   | 16 KB     |            |   0%
# incremental-21.3.0   | 16 KB     | #########7 |  97%
# incremental-21.3.0   | 16 KB     | ########## | 100%
#
# wordcloud-1.8.1      | 196 KB    |            |   0%
# wordcloud-1.8.1      | 196 KB    | 8          |   8%
# wordcloud-1.8.1      | 196 KB    | ########## | 100%
#
# openssl-1.1.1o       | 5.7 MB    |            |   0%
# openssl-1.1.1o       | 5.7 MB    | #2         |  12%
# openssl-1.1.1o       | 5.7 MB    | ####1      |  42%
# openssl-1.1.1o       | 5.7 MB    | ######6    |  66%
# openssl-1.1.1o       | 5.7 MB    | ########9  |  89%
# openssl-1.1.1o       | 5.7 MB    | ########## | 100%
#
# tenacity-8.0.1       | 21 KB     |            |   0%
# tenacity-8.0.1       | 21 KB     | #######5   |  76%
# tenacity-8.0.1       | 21 KB     | ########## | 100%
#
# asttokens-2.0.5      | 21 KB     |            |   0%
# asttokens-2.0.5      | 21 KB     | ########## | 100%
#
# scrapy-2.6.1         | 386 KB    |            |   0%
# scrapy-2.6.1         | 386 KB    | ########## | 100%
# scrapy-2.6.1         | 386 KB    | ########## | 100%
#
# colorcet-3.0.0       | 1.5 MB    |            |   0%
# colorcet-3.0.0       | 1.5 MB    | 1          |   1%
# colorcet-3.0.0       | 1.5 MB    | #7         |  17%
# colorcet-3.0.0       | 1.5 MB    | ##7        |  27%
# colorcet-3.0.0       | 1.5 MB    | ####4      |  45%
# colorcet-3.0.0       | 1.5 MB    | ########   |  80%
# colorcet-3.0.0       | 1.5 MB    | ########## | 100%
# colorcet-3.0.0       | 1.5 MB    | ########## | 100%
#
# googleapis-common-pr | 123 KB    |            |   0%
# googleapis-common-pr | 123 KB    | #2         |  13%
# googleapis-common-pr | 123 KB    | ########## | 100%
# googleapis-common-pr | 123 KB    | ########## | 100%
#
# queuelib-1.6.2       | 14 KB     |            |   0%
# queuelib-1.6.2       | 14 KB     | ########## | 100%
# queuelib-1.6.2       | 14 KB     | ########## | 100%
#
# boto3-1.24.7         | 71 KB     |            |   0%
# boto3-1.24.7         | 71 KB     | ##2        |  22%
# boto3-1.24.7         | 71 KB     | ########## | 100%
#
# google-cloud-core-2. | 27 KB     |            |   0%
# google-cloud-core-2. | 27 KB     | #####9     |  59%
# google-cloud-core-2. | 27 KB     | ########## | 100%
#
# aiosignal-1.2.0      | 12 KB     |            |   0%
# aiosignal-1.2.0      | 12 KB     | ########## | 100%
#
# pyct-0.4.6           | 3 KB      |            |   0%
# pyct-0.4.6           | 3 KB      | ########## | 100%
# pyct-0.4.6           | 3 KB      | ########## | 100%
#
# plotly-5.8.2         | 6.9 MB    |            |   0%
# plotly-5.8.2         | 6.9 MB    |            |   0%
# plotly-5.8.2         | 6.9 MB    | #1         |  11%
# plotly-5.8.2         | 6.9 MB    | ######2    |  63%
# plotly-5.8.2         | 6.9 MB    | ########## | 100%
# plotly-5.8.2         | 6.9 MB    | ########## | 100%
#
# ca-certificates-2022 | 180 KB    |            |   0%
# ca-certificates-2022 | 180 KB    | ########## | 100%
#
# intake-0.6.5         | 115 KB    |            |   0%
# intake-0.6.5         | 115 KB    | #3         |  14%
# intake-0.6.5         | 115 KB    | ########## | 100%
# intake-0.6.5         | 115 KB    | ########## | 100%
#
# python-fastjsonschem | 243 KB    |            |   0%
# python-fastjsonschem | 243 KB    | ########## | 100%
# python-fastjsonschem | 243 KB    | ########## | 100%
#
# pyasn1-modules-0.2.7 | 60 KB     |            |   0%
# pyasn1-modules-0.2.7 | 60 KB     | ########## | 100%
# pyasn1-modules-0.2.7 | 60 KB     | ########## | 100%
#
# google-crc32c-1.1.2  | 26 KB     |            |   0%
# google-crc32c-1.1.2  | 26 KB     | ######     |  60%
# google-crc32c-1.1.2  | 26 KB     | ########## | 100%
#
# protego-0.2.1        | 2.6 MB    |            |   0%
# protego-0.2.1        | 2.6 MB    |            |   1%
# protego-0.2.1        | 2.6 MB    | #########8 |  99%
# protego-0.2.1        | 2.6 MB    | ########## | 100%
#
# cachetools-5.0.0     | 12 KB     |            |   0%
# cachetools-5.0.0     | 12 KB     | ########## | 100%
# cachetools-5.0.0     | 12 KB     | ########## | 100%
#
# pyu2f-0.1.5          | 31 KB     |            |   0%
# pyu2f-0.1.5          | 31 KB     | ########## | 100%
# pyu2f-0.1.5          | 31 KB     | ########## | 100%
#
# w3lib-1.22.0         | 21 KB     |            |   0%
# w3lib-1.22.0         | 21 KB     | #######5   |  75%
# w3lib-1.22.0         | 21 KB     | ########## | 100%
#
# markdown-3.3.7       | 67 KB     |            |   0%
# markdown-3.3.7       | 67 KB     | ########## | 100%
#
# itemloaders-1.0.4    | 14 KB     |            |   0%
# itemloaders-1.0.4    | 14 KB     | ########## | 100%
# itemloaders-1.0.4    | 14 KB     | ########## | 100%
#
# jmespath-1.0.0       | 21 KB     |            |   0%
# jmespath-1.0.0       | 21 KB     | #######7   |  78%
# jmespath-1.0.0       | 21 KB     | ########## | 100%
#
# twisted-22.4.0       | 5.1 MB    |            |   0%
# twisted-22.4.0       | 5.1 MB    |            |   0%
# twisted-22.4.0       | 5.1 MB    | 2          |   3%
# twisted-22.4.0       | 5.1 MB    | 6          |   6%
# twisted-22.4.0       | 5.1 MB    | #5         |  15%
# twisted-22.4.0       | 5.1 MB    | ###9       |  39%
# twisted-22.4.0       | 5.1 MB    | #########  |  90%
# twisted-22.4.0       | 5.1 MB    | ########## | 100%
#
# google-auth-2.7.0    | 87 KB     |            |   0%
# google-auth-2.7.0    | 87 KB     | ########## | 100%
# google-auth-2.7.0    | 87 KB     | ########## | 100%
#
# hvplot-0.8.0         | 3.0 MB    |            |   0%
# hvplot-0.8.0         | 3.0 MB    |            |   1%
# hvplot-0.8.0         | 3.0 MB    | ##7        |  28%
# hvplot-0.8.0         | 3.0 MB    | #######    |  71%
# hvplot-0.8.0         | 3.0 MB    | ########## | 100%
# hvplot-0.8.0         | 3.0 MB    | ########## | 100%
#
# s3transfer-0.6.0     | 55 KB     |            |   0%
# s3transfer-0.6.0     | 55 KB     | ##8        |  29%
# s3transfer-0.6.0     | 55 KB     | ########## | 100%
#
# gensim-4.2.0         | 22.3 MB   |            |   0%
# gensim-4.2.0         | 22.3 MB   |            |   0%
# gensim-4.2.0         | 22.3 MB   |            |   1%
# gensim-4.2.0         | 22.3 MB   | 2          |   2%
# gensim-4.2.0         | 22.3 MB   | 3          |   4%
# gensim-4.2.0         | 22.3 MB   | 4          |   5%
# gensim-4.2.0         | 22.3 MB   | 6          |   6%
# gensim-4.2.0         | 22.3 MB   | 7          |   7%
# gensim-4.2.0         | 22.3 MB   | 8          |   8%
# gensim-4.2.0         | 22.3 MB   | #5         |  16%
# gensim-4.2.0         | 22.3 MB   | ###3       |  33%
# gensim-4.2.0         | 22.3 MB   | #####6     |  57%
# gensim-4.2.0         | 22.3 MB   | #######1   |  71%
# gensim-4.2.0         | 22.3 MB   | ########7  |  88%
# gensim-4.2.0         | 22.3 MB   | ########## | 100%
#
# libprotobuf-3.19.1   | 1.9 MB    |            |   0%
# libprotobuf-3.19.1   | 1.9 MB    |            |   1%
# libprotobuf-3.19.1   | 1.9 MB    | ##7        |  28%
# libprotobuf-3.19.1   | 1.9 MB    | ########7  |  88%
# libprotobuf-3.19.1   | 1.9 MB    | ########## | 100%
#
# automat-20.2.0       | 30 KB     |            |   0%
# automat-20.2.0       | 30 KB     | #####3     |  54%
# automat-20.2.0       | 30 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
pip install hlda
# Out:
# Collecting hlda
#   Downloading hlda-0.3.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: numpy in c:\users\de\anaconda3\lib\site-packages (from hlda) (1.20.3)
# Installing collected packages: hlda
# Successfully installed hlda-0.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
stopset = stopwords.words('english') + list(string.punctuation) + ['will', 'also', 'said']

# %%
pip install risotto
# Out:
# Collecting risottoNote: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\De\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\De\\AppData\\Local\\Temp\\pip-install-57gmtcmj\\risotto_872cd57fd2e649e69efa564336afb72a\\setup.py'"'"'; __file__='"'"'C:\\Users\\De\\AppData\\Local\\Temp\\pip-install-57gmtcmj\\risotto_872cd57fd2e649e69efa564336afb72a\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\De\AppData\Local\Temp\pip-pip-egg-info-hq828q29'
#          cwd: C:\Users\De\AppData\Local\Temp\pip-install-57gmtcmj\risotto_872cd57fd2e649e69efa564336afb72a\
#     Complete output (11 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\De\AppData\Local\Temp\pip-install-57gmtcmj\risotto_872cd57fd2e649e69efa564336afb72a\setup.py", line 36, in <module>
#         ext_modules=cythonize("risotto/_risotto.pyx"),
#       File "C:\Users\De\anaconda3\lib\site-packages\Cython\Build\Dependencies.py", line 970, in cythonize
#         module_list, module_metadata = create_extension_list(
#       File "C:\Users\De\anaconda3\lib\site-packages\Cython\Build\Dependencies.py", line 816, in create_extension_list
#         for file in nonempty(sorted(extended_iglob(filepattern)), "'%s' doesn't match any files" % filepattern):
#       File "C:\Users\De\anaconda3\lib\site-packages\Cython\Build\Dependencies.py", line 114, in nonempty
#         raise ValueError(error_msg)
#     ValueError: 'risotto/_risotto.pyx' doesn't match any files
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/82/ed/b9e21011e60f2981f641424dee8e0e764a2bf5840ad3b5ee4a99359f5329/risotto-0.0.3.tar.gz#sha256=d84861124fa00b2325cd341407047ec3bbd824d9a153629a598dedfd4dc440bf (from https://pypi.org/simple/risotto/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\De\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\De\\AppData\\Local\\Temp\\pip-install-57gmtcmj\\risotto_5f3faf8ee5ca48e1b9c2bf36012c0432\\setup.py'"'"'; __file__='"'"'C:\\Users\\De\\AppData\\Local\\Temp\\pip-install-57gmtcmj\\risotto_5f3faf8ee5ca48e1b9c2bf36012c0432\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\De\AppData\Local\Temp\pip-pip-egg-info-wwigp23z'
#          cwd: C:\Users\De\AppData\Local\Temp\pip-install-57gmtcmj\risotto_5f3faf8ee5ca48e1b9c2bf36012c0432\
#     Complete output (11 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\De\AppData\Local\Temp\pip-install-57gmtcmj\risotto_5f3faf8ee5ca48e1b9c2bf36012c0432\setup.py", line 36, in <module>
#         ext_modules=cythonize("risotto/_risotto.pyx"),
#       File "C:\Users\De\anaconda3\lib\site-packages\Cython\Build\Dependencies.py", line 970, in cythonize
#         module_list, module_metadata = create_extension_list(
#       File "C:\Users\De\anaconda3\lib\site-packages\Cython\Build\Dependencies.py", line 816, in create_extension_list
#         for file in nonempty(sorted(extended_iglob(filepattern)), "'%s' doesn't match any files" % filepattern):
#       File "C:\Users\De\anaconda3\lib\site-packages\Cython\Build\Dependencies.py", line 114, in nonempty
#         raise ValueError(error_msg)
#     ValueError: 'risotto/_risotto.pyx' doesn't match any files
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/96/8f/69e3ac5446226c235c0cc488f24930b5db4587dc0800bf022a670d7a6e45/risotto-0.0.2.tar.gz#sha256=0e2c2812b7bf2f4c1e47c38a16f8454db4992c061e88e0b41a6230048b3a2f9e (from https://pypi.org/simple/risotto/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\De\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\De\\AppData\\Local\\Temp\\pip-install-57gmtcmj\\risotto_5c329da604ad4895918b4a164c365fdc\\setup.py'"'"'; __file__='"'"'C:\\Users\\De\\AppData\\Local\\Temp\\pip-install-57gmtcmj\\risotto_5c329da604ad4895918b4a164c365fdc\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\De\AppData\Local\Temp\pip-pip-egg-info-rfqokrun'
#          cwd: C:\Users\De\AppData\Local\Temp\pip-install-57gmtcmj\risotto_5c329da604ad4895918b4a164c365fdc\
#     Complete output (11 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\De\AppData\Local\Temp\pip-install-57gmtcmj\risotto_5c329da604ad4895918b4a164c365fdc\setup.py", line 35, in <module>
#         ext_modules=cythonize("risotto/_risotto.pyx"),
#       File "C:\Users\De\anaconda3\lib\site-packages\Cython\Build\Dependencies.py", line 970, in cythonize
#         module_list, module_metadata = create_extension_list(
#       File "C:\Users\De\anaconda3\lib\site-packages\Cython\Build\Dependencies.py", line 816, in create_extension_list
#         for file in nonempty(sorted(extended_iglob(filepattern)), "'%s' doesn't match any files" % filepattern):
#       File "C:\Users\De\anaconda3\lib\site-packages\Cython\Build\Dependencies.py", line 114, in nonempty
#         raise ValueError(error_msg)
#     ValueError: 'risotto/_risotto.pyx' doesn't match any files
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/b5/fc/57556b4343cf29bf6279937e741278193bf8f528c23329d5d6ddde645de8/risotto-0.0.1.tar.gz#sha256=294da746707817c1490ce1f7ab88155f26fb6644b7ff0daef2cbed01a2690115 (from https://pypi.org/simple/risotto/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Could not find a version that satisfies the requirement risotto (from versions: 0.0.1, 0.0.2, 0.0.3)
# ERROR: No matching distribution found for risotto
#   Using cached risotto-0.0.3.tar.gz (115 kB)
#   Using cached risotto-0.0.2.tar.gz (115 kB)
#   Using cached risotto-0.0.1.tar.gz (115 kB)
